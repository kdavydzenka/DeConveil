# %% [markdown]
# ## DeConveil test

# %%
import os
import pickle as pkl
import pandas as pd
import numpy as np

# %%
import pydeseq2
from pydeseq2.dds import DeseqDataSet
from pydeseq2.default_inference import DefaultInference
from pydeseq2.ds import DeseqStats

# %%
from pydeseq2.utils import build_design_matrix
from deconveil.dds import deconveil_fit
from deconveil.inference import Inference
from deconveil.default_inference import DefInference
import deconveil.utils_CNaware
from deconveil import deconveil_fit
from deconveil.ds import deconveil_stats

# %% [markdown]
# ### Functions to run PyDESeq2 & DeConveil

# %%
def run_pydeseq2(rna_counts, metadata, output_path, design_factors="condition", alpha=0.05):
    """
    Runs PyDESeq2 analysis and saves the results.

    Parameters:
        rna_counts (pd.DataFrame): Count matrix with genes as rows and samples as columns.
        metadata (pd.DataFrame): Metadata for the samples with design factors.
        output_path (str): Directory to save the results.
        design_factors (str): Column in metadata to use for design.
        alpha (float): Significance level for statistical tests.
    """
    os.makedirs(output_path, exist_ok=True)
    
    # Initialize DESeq2 analysis
    inference = DefaultInference(n_cpus=8)
    dds = DeseqDataSet(
        counts=rna_counts,
        metadata=metadata,
        design_factors="condition",
        refit_cooks=True,
        inference=inference,
    )

    # Fit DESeq2 model
    dds.fit_size_factors()
    dds.fit_genewise_dispersions()
    dds.fit_dispersion_trend()
    dds.fit_dispersion_prior()
    dds.fit_MAP_dispersions()
    dds.fit_LFC()
    dds.calculate_cooks()
    
    if dds.refit_cooks:
        dds.refit()

    # Perform statistical analysis
    stat_res_pydeseq = DeseqStats(dds, alpha=alpha, cooks_filter=True, independent_filter=True)
    stat_res_pydeseq.run_wald_test()

    if stat_res_pydeseq.cooks_filter:
        stat_res_pydeseq._cooks_filtering()
    stat_res_pydeseq.p_values

    if stat_res_pydeseq.independent_filter:
        stat_res_pydeseq._independent_filtering()
    else:
        stat_res_pydeseq._p_value_adjustment()

    # Log-fold change shrinkage
    stat_res_pydeseq.lfc_shrink(coeff="condition_B_vs_A")
    stat_res_pydeseq.summary()

    # Save results
    results_path = os.path.join(output_path, "res_CNnaive.csv")
    stat_res_pydeseq.results_df.to_csv(results_path)
    return(stat_res_pydeseq.results_df)

# %%
def run_deconveil(rna_counts, metadata, cnv, output_path, design_factors="condition", alpha=0.05):
    """
    Runs DeConveil analysis and saves the results.

    Parameters:
        rna_counts (pd.DataFrame): Count matrix with genes as rows and samples as columns.
        metadata (pd.DataFrame): Metadata for the samples with design factors.
        cnv (pd.DataFrame): Copy number variation (CNV) data matrix  with genes as rows and samples as columns.
        output_path (str): Directory to save the results.
        design_factors (str): Column in metadata to use for design.
        alpha (float): Significance level for statistical tests.
    """
    os.makedirs(output_path, exist_ok=True)
    
    # Initialize DeConveil inference
    inference = DefInference(n_cpus=8)

    # Fit DeConveil model
    dds = deconveil_fit(
        counts=rna_counts,
        metadata=metadata,
        cnv=cnv,
        design_factors=design_factors,
        inference=inference,
        refit_cooks=True
    )
    dds.fit_size_factors()
    dds.fit_genewise_dispersions()
    dds.fit_dispersion_trend()
    dds.fit_dispersion_prior()
    dds.fit_MAP_dispersions()
    dds.fit_LFC()
    dds.calculate_cooks()

    if dds.refit_cooks:
        dds.refit()  # Replace outlier counts

    # Statistical analysis
    stat_res_deconveil = deconveil_stats(
        dds, 
        alpha=alpha, 
        independent_filter=True, 
        cooks_filter=True
    )
    stat_res_deconveil.run_wald_test()

    if stat_res_deconveil.independent_filter:
        stat_res_deconveil._independent_filtering()
    else:
        stat_res_deconveil._p_value_adjustment()

    # Log-fold change shrinkage
    stat_res_deconveil.lfc_shrink(coeff="condition_B_vs_A")
    stat_res_deconveil.summary()

    # Save results
    results_path = os.path.join(output_path, "res_CNaware.csv")
    stat_res_deconveil.results_df.to_csv(results_path)
    return(stat_res_deconveil.results_df)

# %% [markdown]
# ### Examples of usage | Perform Inference and Statistical test

# %%
# Test simulated data
#DATA_PATH = "/Users/katsiarynadavydzenka/Documents/PhD_AI/DeConveil/datasets/"
#rna_counts = pd.read_csv(os.path.join(DATA_PATH, "rna_counts.csv"), index_col=0)
#rna_counts = rna_counts.T
#metadata = pd.read_csv(os.path.join(DATA_PATH, "metadata.csv"), index_col=0)
#cnv = pd.read_csv(os.path.join(DATA_PATH, "cnv.csv"), index_col=0)
#cnv = cnv.T

# %%
#__name__ == "__main__":

# Load Pan-cancer data
DATA_PATH = "/Users/katsiarynadavydzenka/Documents/PhD_AI/TCGA/STAD/test"
rna_counts = pd.read_csv(os.path.join(DATA_PATH, "rna.csv"), index_col=0)
rna_counts = rna_counts.T
metadata = pd.read_csv(os.path.join(DATA_PATH, "metadata.csv"), index_col=0)
cnv = pd.read_csv(os.path.join(DATA_PATH, "cnv.csv"), index_col=0)
cnv = cnv.T

# Run PyDESeq2
pydeseq2_output_path = "/Users/katsiarynadavydzenka/Documents/PhD_AI/deconveilCaseStudies/results/STAD/"
run_pydeseq2(rna_counts, metadata, pydeseq2_output_path)

# Run DeConveil
deconveil_output_path = "/Users/katsiarynadavydzenka/Documents/PhD_AI/deconveilCaseStudies/results/STAD/"
run_deconveil(rna_counts, metadata, cnv, deconveil_output_path)
# Out:
# Fitting size factors...
# ... done in 0.04 seconds.
#
# Fitting dispersions...
# ... done in 1.72 seconds.
#
# Fitting dispersion trend curve...
# ... done in 0.27 seconds.
#
# Fitting MAP dispersions...
# ... done in 2.35 seconds.
#
# Fitting LFCs...
# ... done in 1.05 seconds.
#
# Calculating cook's distance...
# ... done in 0.08 seconds.
#
# Replacing 556 outlier genes.
#
# Fitting dispersions...
# ... done in 0.09 seconds.
#
# Fitting MAP dispersions...
# ... done in 0.08 seconds.
#
# Fitting LFCs...
# ... done in 0.07 seconds.
#
# Running Wald tests...
# ... done in 0.60 seconds.
#
# Fitting MAP LFCs...
# ... done in 2.06 seconds.
# Log2 fold change & Wald test p-value: condition B vs A
#               baseMean  log2FoldChange     lfcSE      stat    pvalue      padj
# A1BG-AS1     29.745399       -0.056891  0.230193 -0.280632  0.778993  0.842817
# A2ML1     29319.797526       -0.435021  0.772831 -2.971114  0.002967  0.008881
# A4GALT     1271.315666       -0.260028  0.189516 -1.493597  0.135281  0.215238
# A4GNT       455.611732       -1.856749  0.661577 -3.532261  0.000412  0.001633
# AAAS       2091.957826        0.232250  0.104167  2.352868  0.018629  0.041883
# ...                ...             ...       ...       ...       ...       ...
# ZXDC       1591.210284        0.176666  0.115263  1.578019  0.114561  0.187951
# ZYG11A       42.787794       -0.070358  0.390483 -0.258696  0.795870  0.855010
# ZYG11B     2510.156872       -0.639373  0.162476 -4.280097  0.000019  0.000113
# ZYX       15186.039450       -0.213494  0.182177 -0.587343  0.556974  0.659596
# ZZEF1      5943.322785       -0.564513  0.168914 -3.251203  0.001149  0.003947
#
# [16467 rows x 6 columns]
# Fitting size factors...
# ... done in 0.04 seconds.
#
# Fitting dispersions...
# ... done in 1.74 seconds.
#
# Fitting dispersion trend curve...
# ... done in 0.30 seconds.
#
# Fitting MAP dispersions...
# ... done in 2.22 seconds.
#
# Fitting LFCs...
# ... done in 1.20 seconds.
#
# Calculating cook's distance...
# ... done in 0.08 seconds.
#
# Replacing 499 outlier genes.
#
# Fitting dispersions...
# replace_mask before filtering: (64, 499)
# Number of True values in replace_mask: 697
# replacement_counts_trimmed shape: (61, 499)
# ... done in 0.08 seconds.
#
# Fitting MAP dispersions...
# ... done in 0.09 seconds.
#
# Fitting LFCs...
# ... done in 0.06 seconds.
#
# Running Wald tests...
# ... done in 0.54 seconds.
#
# Fitting MAP LFCs...
# Log2 fold change & Wald test p-value: condition B vs A
#               baseMean  log2FoldChange     lfcSE      stat    pvalue      padj
# A1BG-AS1     29.745399       -0.165771  0.230461 -0.818715  0.412949  0.527916
# A2ML1     29319.797526       -0.224643  0.584151 -3.244299  0.001177  0.004301
# A4GALT     1271.315666       -0.103942  0.187939 -0.625653  0.531542  0.639031
# A4GNT       455.611732       -1.815053  0.665089 -3.485436  0.000491  0.002039
# AAAS       2091.957826        0.188806  0.104111  1.904175  0.056887  0.109230
# ...                ...             ...       ...       ...       ...       ...
# ZXDC       1591.210284        0.083674  0.115131  0.772791  0.439646  0.554807
# ZYG11A       42.787794       -0.200873  0.393102 -0.738468  0.460230  0.573745
# ZYG11B     2510.156872       -0.676494  0.162652 -4.501000  0.000007  0.000051
# ZYX       15186.039450       -0.060125  0.181660  0.208921  0.834510  0.883340
# ZZEF1      5943.322785       -0.323732  0.167991 -1.809046  0.070444  0.130064
#
# [16467 rows x 6 columns]
# ... done in 1.99 seconds.
#               baseMean  log2FoldChange     lfcSE      stat    pvalue      padj
# A1BG-AS1     29.745399       -0.165771  0.230461 -0.818715  0.412949  0.527916
# A2ML1     29319.797526       -0.224643  0.584151 -3.244299  0.001177  0.004301
# A4GALT     1271.315666       -0.103942  0.187939 -0.625653  0.531542  0.639031
# A4GNT       455.611732       -1.815053  0.665089 -3.485436  0.000491  0.002039
# AAAS       2091.957826        0.188806  0.104111  1.904175  0.056887  0.109230
# ...                ...             ...       ...       ...       ...       ...
# ZXDC       1591.210284        0.083674  0.115131  0.772791  0.439646  0.554807
# ZYG11A       42.787794       -0.200873  0.393102 -0.738468  0.460230  0.573745
# ZYG11B     2510.156872       -0.676494  0.162652 -4.501000  0.000007  0.000051
# ZYX       15186.039450       -0.060125  0.181660  0.208921  0.834510  0.883340
# ZZEF1      5943.322785       -0.323732  0.167991 -1.809046  0.070444  0.130064
#
# [16467 rows x 6 columns]

# %% [markdown]
# ### Define gene groups

# %%
pydeseq2_output_path = "/Users/katsiarynadavydzenka/Documents/PhD_AI/deconveilCaseStudies/results/STAD/res_CNnaive.csv"
deconveil_output_path = "/Users/katsiarynadavydzenka/Documents/PhD_AI/deconveilCaseStudies/results/STAD/res_CNaware.csv"

# %%
lfc_cut = 1.0
pval_cut = 0.05

# %%
def process_results(file_path, method):
    df = pd.read_csv(file_path, index_col=0)
    df['isDE'] = (np.abs(df['log2FoldChange']) >= lfc_cut) & (df['padj'] <= pval_cut)
    df['DEtype'] = np.where(
        ~df['isDE'], 
        "n.s.", 
        np.where(df['log2FoldChange'] > 0, "Up-reg", "Down-reg")
    )
    df['method'] = method
    return df[['log2FoldChange', 'padj', 'isDE', 'DEtype', 'method']]
    

def define_gene_groups(res_joint):
    DSGs = res_joint[
        ((res_joint['DEtype_naive'] == "Up-reg") & (res_joint['DEtype_aware'] == "n.s.")) |
        ((res_joint['DEtype_naive'] == "Down-reg") & (res_joint['DEtype_aware'] == "n.s."))
    ].assign(gene_category='DSGs')
    
    DIGs = res_joint[
        ((res_joint['DEtype_naive'] == "Up-reg") & (res_joint['DEtype_aware'] == "Up-reg")) |
        ((res_joint['DEtype_naive'] == "Down-reg") & (res_joint['DEtype_aware'] == "Down-reg"))
    ].assign(gene_category='DIGs')
             
    DCGs = res_joint[
        ((res_joint['DEtype_naive'] == "n.s.") & (res_joint['DEtype_aware'] == "Up-reg")) |
        ((res_joint['DEtype_naive'] == "n.s.") & (res_joint['DEtype_aware'] == "Down-reg"))
    ].assign(gene_category='DCGs')
             
    non_DEGs = res_joint[
        (res_joint['DEtype_naive'] == "n.s.") & (res_joint['DEtype_aware'] == "n.s.")
    ].assign(gene_category='non-DEGs')
             
    return {
        "DSGs": DSGs,
        "DIGs": DIGs,
        "DCGs": DCGs,
        "non_DEGs": non_DEGs
    }

# %%
res_pydeseq = process_results(pydeseq2_output_path, "CN naive")
res_pydeseq.columns = ["logFC", "padj", "isDE", "DEtype", "method"]
res_pydeseq
# Out:
#              logFC      padj   isDE    DEtype    method
# A1BG-AS1 -0.056891  0.842817  False      n.s.  CN naive
# A2ML1    -0.435021  0.008881  False      n.s.  CN naive
# A4GALT   -0.260028  0.215238  False      n.s.  CN naive
# A4GNT    -1.856749  0.001633   True  Down-reg  CN naive
# AAAS      0.232250  0.041883  False      n.s.  CN naive
# ...            ...       ...    ...       ...       ...
# ZXDC      0.176666  0.187951  False      n.s.  CN naive
# ZYG11A   -0.070358  0.855010  False      n.s.  CN naive
# ZYG11B   -0.639373  0.000113  False      n.s.  CN naive
# ZYX      -0.213494  0.659596  False      n.s.  CN naive
# ZZEF1    -0.564513  0.003947  False      n.s.  CN naive
#
# [16467 rows x 5 columns]

# %%
res_deconveil = process_results(deconveil_output_path, "CN aware")
res_deconveil.columns = ["logFC", "padj", "isDE", "DEtype", "method"]
res_deconveil
# Out:
#              logFC      padj   isDE    DEtype    method
# A1BG-AS1 -0.165771  0.527916  False      n.s.  CN aware
# A2ML1    -0.224643  0.004301  False      n.s.  CN aware
# A4GALT   -0.103942  0.639031  False      n.s.  CN aware
# A4GNT    -1.815053  0.002039   True  Down-reg  CN aware
# AAAS      0.188806  0.109230  False      n.s.  CN aware
# ...            ...       ...    ...       ...       ...
# ZXDC      0.083674  0.554807  False      n.s.  CN aware
# ZYG11A   -0.200873  0.573745  False      n.s.  CN aware
# ZYG11B   -0.676494  0.000051  False      n.s.  CN aware
# ZYX      -0.060125  0.883340  False      n.s.  CN aware
# ZZEF1    -0.323732  0.130064  False      n.s.  CN aware
#
# [16467 rows x 5 columns]

# %%
res_joint = pd.concat([
    res_pydeseq.add_suffix("_naive"),
    res_deconveil.add_suffix("_aware")
], axis=1)
res_joint
# Out:
#           logFC_naive  padj_naive  isDE_naive DEtype_naive method_naive  \
# A1BG-AS1    -0.056891    0.842817       False         n.s.     CN naive
# A2ML1       -0.435021    0.008881       False         n.s.     CN naive
# A4GALT      -0.260028    0.215238       False         n.s.     CN naive
# A4GNT       -1.856749    0.001633        True     Down-reg     CN naive
# AAAS         0.232250    0.041883       False         n.s.     CN naive
# ...               ...         ...         ...          ...          ...
# ZXDC         0.176666    0.187951       False         n.s.     CN naive
# ZYG11A      -0.070358    0.855010       False         n.s.     CN naive
# ZYG11B      -0.639373    0.000113       False         n.s.     CN naive
# ZYX         -0.213494    0.659596       False         n.s.     CN naive
# ZZEF1       -0.564513    0.003947       False         n.s.     CN naive
#
#           logFC_aware  padj_aware  isDE_aware DEtype_aware method_aware
# A1BG-AS1    -0.165771    0.527916       False         n.s.     CN aware
# A2ML1       -0.224643    0.004301       False         n.s.     CN aware
# A4GALT      -0.103942    0.639031       False         n.s.     CN aware
# A4GNT       -1.815053    0.002039        True     Down-reg     CN aware
# AAAS         0.188806    0.109230       False         n.s.     CN aware
# ...               ...         ...         ...          ...          ...
# ZXDC         0.083674    0.554807       False         n.s.     CN aware
# ZYG11A      -0.200873    0.573745       False         n.s.     CN aware
# ZYG11B      -0.676494    0.000051       False         n.s.     CN aware
# ZYX         -0.060125    0.883340       False         n.s.     CN aware
# ZZEF1       -0.323732    0.130064       False         n.s.     CN aware
#
# [16467 rows x 10 columns]

# %%
gene_groups = define_gene_groups(res_joint)
gene_groups
# Out:
# {'DSGs':             logFC_naive    padj_naive  isDE_naive DEtype_naive method_naive  \
#  ABCA13         1.165827  8.584955e-03        True       Up-reg     CN naive
#  AC000403.1     1.138668  1.704122e-04        True       Up-reg     CN naive
#  AC005162.2     1.188141  1.289250e-03        True       Up-reg     CN naive
#  AC005550.2     1.074914  4.312995e-02        True       Up-reg     CN naive
#  AC005695.1    -1.144011  5.933413e-03        True     Down-reg     CN naive
#  ...                 ...           ...         ...          ...          ...
#  ZNF354C       -1.046088  1.050798e-04        True     Down-reg     CN naive
#  ZNF697         1.023823  9.743980e-08        True       Up-reg     CN naive
#  ZNF774         1.385296  4.735813e-04        True       Up-reg     CN naive
#  ZSCAN12P1      1.092538  1.336587e-05        True       Up-reg     CN naive
#  ZWILCH         1.137364  1.672803e-10        True       Up-reg     CN naive
#
#              logFC_aware    padj_aware  isDE_aware DEtype_aware method_aware  \
#  ABCA13         0.822969  4.565535e-02       False         n.s.     CN aware
#  AC000403.1     0.994812  9.926747e-04       False         n.s.     CN aware
#  AC005162.2     0.834229  1.892501e-02       False         n.s.     CN aware
#  AC005550.2     0.775675  8.045314e-02       False         n.s.     CN aware
#  AC005695.1    -0.960284  1.716998e-02       False         n.s.     CN aware
#  ...                 ...           ...         ...          ...          ...
#  ZNF354C       -0.929754  5.342352e-04       False         n.s.     CN aware
#  ZNF697         0.816935  2.153311e-05       False         n.s.     CN aware
#  ZNF774         0.526987  5.347757e-02       False         n.s.     CN aware
#  ZSCAN12P1      0.869446  5.122636e-04       False         n.s.     CN aware
#  ZWILCH         0.978332  3.690097e-08       False         n.s.     CN aware
#
#             gene_category
#  ABCA13              DSGs
#  AC000403.1          DSGs
#  AC005162.2          DSGs
#  AC005550.2          DSGs
#  AC005695.1          DSGs
#  ...                  ...
#  ZNF354C             DSGs
#  ZNF697              DSGs
#  ZNF774              DSGs
#  ZSCAN12P1           DSGs
#  ZWILCH              DSGs
#
#  [393 rows x 11 columns],
#  'DIGs':          logFC_naive    padj_naive  isDE_naive DEtype_naive method_naive  \
#  A4GNT      -1.856749  1.632919e-03        True     Down-reg     CN naive
#  AADAC      -2.981289  4.345567e-08        True     Down-reg     CN naive
#  AADACL2    -2.424497  2.244352e-06        True     Down-reg     CN naive
#  AARD       -2.263282  3.293337e-07        True     Down-reg     CN naive
#  ABAT       -1.332814  1.128837e-05        True     Down-reg     CN naive
#  ...              ...           ...         ...          ...          ...
#  ZNF835     -1.148487  4.023264e-04        True     Down-reg     CN naive
#  ZNF853     -1.211738  1.631199e-04        True     Down-reg     CN naive
#  ZSCAN18    -1.599559  1.769168e-08        True     Down-reg     CN naive
#  ZSCAN23    -1.764111  2.899703e-08        True     Down-reg     CN naive
#  ZWINT       1.234412  6.131021e-06        True       Up-reg     CN naive
#
#           logFC_aware    padj_aware  isDE_aware DEtype_aware method_aware  \
#  A4GNT      -1.815053  2.039426e-03        True     Down-reg     CN aware
#  AADAC      -2.713324  4.799050e-07        True     Down-reg     CN aware
#  AADACL2    -2.549461  9.634421e-07        True     Down-reg     CN aware
#  AARD       -2.538989  1.620575e-08        True     Down-reg     CN aware
#  ABAT       -1.379131  6.588832e-06        True     Down-reg     CN aware
#  ...              ...           ...         ...          ...          ...
#  ZNF835     -1.220064  1.920513e-04        True     Down-reg     CN aware
#  ZNF853     -1.458890  7.242720e-06        True     Down-reg     CN aware
#  ZSCAN18    -1.717198  2.303486e-09        True     Down-reg     CN aware
#  ZSCAN23    -1.912382  3.441829e-09        True     Down-reg     CN aware
#  ZWINT       1.044596  1.283731e-04        True       Up-reg     CN aware
#
#          gene_category
#  A4GNT            DIGs
#  AADAC            DIGs
#  AADACL2          DIGs
#  AARD             DIGs
#  ABAT             DIGs
#  ...               ...
#  ZNF835           DIGs
#  ZNF853           DIGs
#  ZSCAN18          DIGs
#  ZSCAN23          DIGs
#  ZWINT            DIGs
#
#  [2341 rows x 11 columns],
#  'DCGs':              logFC_naive  padj_naive  isDE_naive DEtype_naive method_naive  \
#  AAMDC          -0.772543    0.000111       False         n.s.     CN naive
#  AC004803.1     -0.902340    0.000266       False         n.s.     CN naive
#  AC004947.1     -0.988643    0.009407       False         n.s.     CN naive
#  AC004951.4     -0.795252    0.020440       False         n.s.     CN naive
#  AC005682.1     -0.988942    0.000966       False         n.s.     CN naive
#  ...                  ...         ...         ...          ...          ...
#  ZNF404         -0.907456    0.000306       False         n.s.     CN naive
#  ZNF704         -0.713948    0.005017       False         n.s.     CN naive
#  ZNF793-AS1     -0.967508    0.002260       False         n.s.     CN naive
#  ZP1            -0.964555    0.008921       False         n.s.     CN naive
#  ZSCAN16-AS1    -0.956747    0.000004       False         n.s.     CN naive
#
#               logFC_aware    padj_aware  isDE_aware DEtype_aware method_aware  \
#  AAMDC          -1.136798  1.499220e-08        True     Down-reg     CN aware
#  AC004803.1     -1.023223  4.077750e-05        True     Down-reg     CN aware
#  AC004947.1     -1.219671  2.058499e-03        True     Down-reg     CN aware
#  AC004951.4     -1.050264  3.309991e-03        True     Down-reg     CN aware
#  AC005682.1     -1.304768  2.188599e-05        True     Down-reg     CN aware
#  ...                  ...           ...         ...          ...          ...
#  ZNF404         -1.135038  8.389653e-06        True     Down-reg     CN aware
#  ZNF704         -1.202010  4.570121e-06        True     Down-reg     CN aware
#  ZNF793-AS1     -1.041123  1.146303e-03        True     Down-reg     CN aware
#  ZP1            -1.095518  3.697329e-03        True     Down-reg     CN aware
#  ZSCAN16-AS1    -1.092654  1.478684e-07        True     Down-reg     CN aware
#
#              gene_category
#  AAMDC                DCGs
#  AC004803.1           DCGs
#  AC004947.1           DCGs
#  AC004951.4           DCGs
#  AC005682.1           DCGs
#  ...                   ...
#  ZNF404               DCGs
#  ZNF704               DCGs
#  ZNF793-AS1           DCGs
#  ZP1                  DCGs
#  ZSCAN16-AS1          DCGs
#
#  [302 rows x 11 columns],
#  'non_DEGs':           logFC_naive  padj_naive  isDE_naive DEtype_naive method_naive  \
#  A1BG-AS1    -0.056891    0.842817       False         n.s.     CN naive
#  A2ML1       -0.435021    0.008881       False         n.s.     CN naive
#  A4GALT      -0.260028    0.215238       False         n.s.     CN naive
#  AAAS         0.232250    0.041883       False         n.s.     CN naive
#  AACS        -0.284720    0.229145       False         n.s.     CN naive
#  ...               ...         ...         ...          ...          ...
#  ZXDC         0.176666    0.187951       False         n.s.     CN naive
#  ZYG11A      -0.070358    0.855010       False         n.s.     CN naive
#  ZYG11B      -0.639373    0.000113       False         n.s.     CN naive
#  ZYX         -0.213494    0.659596       False         n.s.     CN naive
#  ZZEF1       -0.564513    0.003947       False         n.s.     CN naive
#
#            logFC_aware  padj_aware  isDE_aware DEtype_aware method_aware  \
#  A1BG-AS1    -0.165771    0.527916       False         n.s.     CN aware
#  A2ML1       -0.224643    0.004301       False         n.s.     CN aware
#  A4GALT      -0.103942    0.639031       False         n.s.     CN aware
#  AAAS         0.188806    0.109230       False         n.s.     CN aware
#  AACS        -0.360522    0.106405       False         n.s.     CN aware
#  ...               ...         ...         ...          ...          ...
#  ZXDC         0.083674    0.554807       False         n.s.     CN aware
#  ZYG11A      -0.200873    0.573745       False         n.s.     CN aware
#  ZYG11B      -0.676494    0.000051       False         n.s.     CN aware
#  ZYX         -0.060125    0.883340       False         n.s.     CN aware
#  ZZEF1       -0.323732    0.130064       False         n.s.     CN aware
#
#           gene_category
#  A1BG-AS1      non-DEGs
#  A2ML1         non-DEGs
#  A4GALT        non-DEGs
#  AAAS          non-DEGs
#  AACS          non-DEGs
#  ...                ...
#  ZXDC          non-DEGs
#  ZYG11A        non-DEGs
#  ZYG11B        non-DEGs
#  ZYX           non-DEGs
#  ZZEF1         non-DEGs
#
#  [13431 rows x 11 columns]}

# %%
# Extract each gene category

# Dosage-sensitive genes
d_sensitive = (
    gene_groups['DSGs']
    .rename(columns={
        'logFC_aware': 'log2FC',
        'padj_aware': 'padj',
        'isDE_aware': 'isDE',
        'DEtype_aware': 'DEtype',
        'method_aware': 'method',
        'gene_category': 'gene_group'
    })[['log2FC', 'padj', 'isDE', 'DEtype', 'method', 'gene_group']]
)

# Dosage-insensitive genes
d_insensitive = (
    gene_groups['DIGs']
    .rename(columns={
        'logFC_aware': 'log2FC',
        'padj_aware': 'padj',
        'isDE_aware': 'isDE',
        'DEtype_aware': 'DEtype',
        'method_aware': 'method',
        'gene_category': 'gene_group'
    })[['log2FC', 'padj', 'isDE', 'DEtype', 'method', 'gene_group']]
)

# Dosage-compensated genes
d_compensated = (
    gene_groups['DCGs']
    .rename(columns={
        'logFC_aware': 'log2FC',
        'padj_aware': 'padj',
        'isDE_aware': 'isDE',
        'DEtype_aware': 'DEtype',
        'method_aware': 'method',
        'gene_category': 'gene_group'
    })[['log2FC', 'padj', 'isDE', 'DEtype', 'method', 'gene_group']]
)

# non-DEGs

non_DEGs = (
    gene_groups['non_DEGs']
    .rename(columns={
        'logFC_aware': 'log2FC',
        'padj_aware': 'padj',
        'isDE_aware': 'isDE',
        'DEtype_aware': 'DEtype',
        'method_aware': 'method',
        'gene_category': 'gene_group'
    })[['log2FC', 'padj', 'isDE', 'DEtype', 'method', 'gene_group']]
)

cn_aware = pd.concat([d_sensitive, d_insensitive, d_compensated, non_DEGs], axis=0)

# %%
# Dosage-sensitive genes
d_sensitive = (
    gene_groups['DSGs']
    .rename(columns={
        'logFC_naive': 'log2FC',
        'padj_naive': 'padj',
        'isDE_naive': 'isDE',
        'DEtype_naive': 'DEtype',
        'method_naive': 'method',
        'gene_category': 'gene_group'
    })[['log2FC', 'padj', 'isDE', 'DEtype', 'method', 'gene_group']]
)

# Dosage-insensitive genes
d_insensitive = (
    gene_groups['DIGs']
    .rename(columns={
        'logFC_naive': 'log2FC',
        'padj_naive': 'padj',
        'isDE_naive': 'isDE',
        'DEtype_naive': 'DEtype',
        'method_naive': 'method',
        'gene_category': 'gene_group'
    })[['log2FC', 'padj', 'isDE', 'DEtype', 'method', 'gene_group']]
)

# Dosage-compensated genes
d_compensated = (
    gene_groups['DCGs']
    .rename(columns={
        'logFC_naive': 'log2FC',
        'padj_naive': 'padj',
        'isDE_naive': 'isDE',
        'DEtype_naive': 'DEtype',
        'method_naive': 'method',
        'gene_category': 'gene_group'
    })[['log2FC', 'padj', 'isDE', 'DEtype', 'method', 'gene_group']]
)

# non-DEGs

non_DEGs = (
    gene_groups['non_DEGs']
    .rename(columns={
        'logFC_naive': 'log2FC',
        'padj_naive': 'padj',
        'isDE_naive': 'isDE',
        'DEtype_naive': 'DEtype',
        'method_naive': 'method',
        'gene_category': 'gene_group'
    })[['log2FC', 'padj', 'isDE', 'DEtype', 'method', 'gene_group']]
)

cn_naive = pd.concat([d_sensitive, d_insensitive, d_compensated, non_DEGs], axis=0)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plot_data = pd.concat([cn_naive, cn_aware], axis=0)
plot_data['gene_group'] = plot_data['gene_group'].astype("category")
plot_data['-log10(padj)'] = -np.log10(plot_data['padj'])

gene_group_colors = {
    "DIGs": "#8F3931FF", 
    "DSGs": "#FFB977", 
    "DCGs": "#FAE48BFF", 
    "non-DEGs": "#ADB6B6FF"
}

lfc_cut = 1
pval_cut = 0.05

# %% [markdown]
# ### Volcano plot

# %%
plt.figure(figsize=(5, 5))

# Scatterplot for "DIGs" and "non-DEGs"
scatter1 = sns.scatterplot(
    data=plot_data[plot_data['gene_group'].isin(["DIGs", "non-DEGs"])],
    x='log2FC', y='-log10(padj)', hue='gene_group', palette=gene_group_colors,
    s=10, alpha=0.3, legend="brief"
)

# Scatterplot for "DSGs" and "DCGs"
scatter2 = sns.scatterplot(
    data=plot_data[plot_data['gene_group'].isin(["DSGs", "DCGs"])],
    x='log2FC', y='-log10(padj)', hue='gene_group', palette=gene_group_colors,
    s=50, alpha=0.5, legend=""
)

plt.axvline(x=-lfc_cut, color='gray', linestyle='--')
plt.axvline(x=lfc_cut, color='gray', linestyle='--')
plt.axhline(y=-np.log10(pval_cut), color='gray', linestyle='--')
plt.xlabel('Log2 Fold Change', fontsize=14)
plt.ylabel('-Log10 P-value', fontsize=14)
plt.xlim(plot_data['log2FC'].min() - 1, plot_data['log2FC'].max() + 1)
plt.ylim(0, plot_data['-log10(padj)'].max() + 1)
handles, labels = scatter1.get_legend_handles_labels()
plt.legend(handles=handles, labels=labels, title='Gene group', loc='upper left', fontsize=12, title_fontsize=14)
plt.grid(True, linestyle='--', alpha=0.7)
sns.set_theme(style="whitegrid")

g = sns.FacetGrid(plot_data, col="method", hue="gene_group", col_order=["CN naive", "CN aware"], height=5, palette=gene_group_colors)
g.map(sns.scatterplot, 'log2FC', '-log10(padj)', alpha=0.6, s=20)
g.set_axis_labels('Log2 Fold Change', '-Log10 P-value')
g.set_titles("{col_name}")
g.add_legend(title="Gene group", title_fontsize=14, fontsize=12)
plt.tight_layout()
plt.show()
